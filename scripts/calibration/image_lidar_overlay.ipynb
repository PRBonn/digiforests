# %% [markdown]
# # LiDAR Image Overlay
# This notebook uses the frontier device extrinsics to generate image-lidar overlays.

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from sensor import Sensor
from scipy.spatial.transform import Rotation as R
import numpy as np
import helper_functions
import cv2
import open3d as o3d
import os

# %%
if not os.path.exists("sample/2025-08-06_15-47-37_rec000_small/"):
    import subprocess
    import zipfile
    print("Downloading...", end="")
    subprocess.run(
        [
            "wget",
            "https://www.ipb.uni-bonn.de/data/digiforest-dataset/data/calibration_example.zip",
            "-q",
            "-nc",
            "-P",
            "sample"
        ],
        check=True,
    )
    print("finished.")

    print("Extracting files...", end="")
    with zipfile.ZipFile("sample/calibration_example.zip", "r") as zip_file:
        zip_file.extractall("sample/")
    print("finished.")

# Set sensor config file and slam folder used for testing overlays.
sensor_yaml = "extrinsics/sensors_frn015-mar23.yaml"
slam_folder = "sample/2025-08-06_15-47-37_rec000_small"

# Load device extrinsics
sensor = Sensor.load_config(Path(sensor_yaml))

# %%
# load a lidar and camera image pair
pcd_folder = os.path.join(slam_folder, "raw_data/raw_clouds")
image_folder = os.path.join(slam_folder , "raw_data/raw_images")
cam_folder = os.path.join(image_folder , "cam_left")

matches = helper_functions.find_closest_images(pcd_folder, cam_folder)
# Iterate through the matches
for pcd_file, image_file in matches:
    print(f"Processing Point Cloud: {pcd_file} -> Closest Image: {image_file}")

    lidar = o3d.io.read_point_cloud(os.path.join(pcd_folder, pcd_file))

    for camera in sensor.cameras:
        image = cv2.imread(os.path.join(image_folder, camera.label, image_file))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # transform lidar points from base frame to camera frame
        lidar_points = np.asarray(lidar.points)
        L_T_LB = sensor.tf.get_transform("base", "lidar") 
        lidar_points_in_lidar = helper_functions.transform_points_tf_matrix(lidar_points.copy(), L_T_LB)

        #  convert lidar points from lidar to camera frame
        C_T_CL = sensor.tf.get_transform("lidar", camera.label)
        lidar_points_in_camera = helper_functions.transform_points_tf_matrix(lidar_points_in_lidar.copy(), C_T_CL)

        # transform lidar points from base frame to camera frame
        lidar_points = np.asarray(lidar.points)
        C_T_CB = sensor.tf.get_transform("base", camera.label)
        lidar_points_in_camera = helper_functions.transform_points_tf_matrix(lidar_points.copy(), C_T_CB)

        # Ensure intrinsics and distortion parameters are numpy arrays with correct shapes (Ate these correct)
        K = np.array(camera.fisheye_intrinsics, dtype=np.float64).reshape(3, 3)
        D = np.array(camera.fisheye_extra_params, dtype=np.float64).reshape(-1, 1)  # OpenCV expects (4,1) or (N,1)

        #(d) Reproject the LiDAR points onto the current image using the fisheye camera projection model: (can be changed to a different reprojection model at a latger stage)
        lidar_points_image, _ = cv2.fisheye.projectPoints(lidar_points_in_camera.reshape(-1, 1, 3).astype(np.float32), np.array([[0.0], [0.0], [0.0]]),np.array([[0.0], [0.0], [0.0]]), K, D)
        lidar_points_image = lidar_points_image.reshape(-1, 2)
        to_keep = np.where((lidar_points_image[:, 0] > 0) & (lidar_points_image[:, 1] > 0) & (lidar_points_image[:, 0] < image.shape[1]) & (lidar_points_image[:, 1] < image.shape[0]) & (lidar_points[:, 2] > 0))
        lidar_points_image = np.round(lidar_points_image[to_keep]).astype(np.uint32) # Convert to (row, column) form (x, y) which is the OpenCV standard.
        depth_pts = lidar_points[to_keep, 2].copy() #Extract the depth associated with each of the image lidar points.

        #(e) Visualize if enabled:
        image_temp = image.copy()

        depth_norm = cv2.normalize(depth_pts, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
        depth_colors = cv2.applyColorMap(depth_norm, cv2.COLORMAP_JET).reshape(-1, 3)

        # Draw blobs for each point
        for i in range(lidar_points_image.shape[0]):
            x, y = lidar_points_image[i]
            color = tuple(int(c) for c in depth_colors[i])  # Convert to tuple for cv2
            cv2.circle(image_temp, (x, y), radius=3, color=color, thickness=-1)  # filled circle

        output_dir = os.path.join(slam_folder, "overlay", camera.label)
        os.makedirs(output_dir, exist_ok=True)

        output_path = os.path.join(output_dir, image_file)
        print(f"Saving overlay image for {camera.label} at {output_path}")
        cv2.imwrite(output_path, cv2.cvtColor(image_temp, cv2.COLOR_RGB2BGR))
        # cv2.imshow("lidar", cv2.cvtColor(image_temp, cv2.COLOR_RGB2BGR))
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
# Out:
# Processing Point Cloud: cloud_1679392256_249250048.ply -> Closest Image: image_1679392256_260410970.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_260410970.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_260410970.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_260410970.png
# Processing Point Cloud: cloud_1679392256_349269760.ply -> Closest Image: image_1679392256_360409070.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_360409070.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_360409070.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_360409070.png
# Processing Point Cloud: cloud_1679392256_449117952.ply -> Closest Image: image_1679392256_460407170.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_460407170.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_460407170.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_460407170.png
# Processing Point Cloud: cloud_1679392256_548911872.ply -> Closest Image: image_1679392256_560405370.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_560405370.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_560405370.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_560405370.png
# Processing Point Cloud: cloud_1679392256_648850944.ply -> Closest Image: image_1679392256_660403370.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_660403370.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_660403370.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_660403370.png
# Processing Point Cloud: cloud_1679392256_748897792.ply -> Closest Image: image_1679392256_760401470.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_760401470.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_760401470.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_760401470.png
# Processing Point Cloud: cloud_1679392256_848883968.ply -> Closest Image: image_1679392256_860399570.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_860399570.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_860399570.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_860399570.png
# Processing Point Cloud: cloud_1679392256_948898816.ply -> Closest Image: image_1679392256_960397570.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392256_960397570.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392256_960397570.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392256_960397570.png
# Processing Point Cloud: cloud_1679392257_048898816.ply -> Closest Image: image_1679392257_60395770.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_60395770.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_60395770.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_60395770.png
# Processing Point Cloud: cloud_1679392257_148893952.ply -> Closest Image: image_1679392257_160393870.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_160393870.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_160393870.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_160393870.png
# Processing Point Cloud: cloud_1679392257_248913664.ply -> Closest Image: image_1679392257_260391970.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_260391970.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_260391970.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_260391970.png
# Processing Point Cloud: cloud_1679392257_348977920.ply -> Closest Image: image_1679392257_360389970.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_360389970.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_360389970.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_360389970.png
# Processing Point Cloud: cloud_1679392257_449033984.ply -> Closest Image: image_1679392257_460388070.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_460388070.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_460388070.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_460388070.png
# Processing Point Cloud: cloud_1679392257_549066752.ply -> Closest Image: image_1679392257_560386270.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_560386270.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_560386270.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_560386270.png
# Processing Point Cloud: cloud_1679392257_649082880.ply -> Closest Image: image_1679392257_660384370.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_660384370.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_660384370.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_660384370.png
# Processing Point Cloud: cloud_1679392257_749098752.ply -> Closest Image: image_1679392257_760382370.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_760382370.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_760382370.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_760382370.png
# Processing Point Cloud: cloud_1679392257_849126912.ply -> Closest Image: image_1679392257_860380470.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_860380470.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_860380470.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_860380470.png
# Processing Point Cloud: cloud_1679392257_949143808.ply -> Closest Image: image_1679392257_960378570.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392257_960378570.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392257_960378570.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392257_960378570.png
# Processing Point Cloud: cloud_1679392258_049152768.ply -> Closest Image: image_1679392258_60376670.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392258_60376670.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392258_60376670.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392258
png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392265_960217402.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392265_960217402.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392265_960217402.png
# Processing Point Cloud: cloud_1679392266_049268992.ply -> Closest Image: image_1679392266_60215502.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_60215502.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_60215502.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_60215502.png
# Processing Point Cloud: cloud_1679392266_149387776.ply -> Closest Image: image_1679392266_160213602.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_160213602.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_160213602.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_160213602.png
# Processing Point Cloud: cloud_1679392266_249420032.ply -> Closest Image: image_1679392266_260211602.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_260211602.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_260211602.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_260211602.png
# Processing Point Cloud: cloud_1679392266_349243904.ply -> Closest Image: image_1679392266_360209602.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_360209602.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_360209602.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_360209602.png
# Processing Point Cloud: cloud_1679392266_449024000.ply -> Closest Image: image_1679392266_460207602.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_460207602.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_460207602.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_460207602.png
# Processing Point Cloud: cloud_1679392266_548754944.ply -> Closest Image: image_1679392266_560205702.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_560205702.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_560205702.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_560205702.png
# Processing Point Cloud: cloud_1679392266_648530944.ply -> Closest Image: image_1679392266_660203802.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_660203802.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_660203802.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_660203802.png
# Processing Point Cloud: cloud_1679392266_748385024.ply -> Closest Image: image_1679392266_760201802.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_760201802.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_760201802.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_760201802.png
# Processing Point Cloud: cloud_1679392266_848301824.ply -> Closest Image: image_1679392266_860199802.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_860199802.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_860199802.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_860199802.png
# Processing Point Cloud: cloud_1679392266_948224768.ply -> Closest Image: image_1679392266_960197802.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392266_960197802.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392266_960197802.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392266_960197802.png
# Processing Point Cloud: cloud_1679392267_048274688.ply -> Closest Image: image_1679392267_60195902.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_60195902.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_60195902.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_60195902.png
# Processing Point Cloud: cloud_1679392267_148408064.ply -> Closest Image: image_1679392267_160194002.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_160194002.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_160194002.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_160194002.png
# Processing Point Cloud: cloud_1679392267_248560896.ply -> Closest Image: image_1679392267_260192002.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_260192002.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_260192002.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_260192002.png
# Processing Point Cloud: cloud_1679392267_348644864.ply -> Closest Image: image_1679392267_360190002.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_360190002.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_360190002.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_360190002.png
# Processing Point Cloud: cloud_1679392267_448648960.ply -> Closest Image: image_1679392267_460188002.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_460188002.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_460188002.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_460188002.png
# Processing Point Cloud: cloud_1679392267_548589824.ply -> Closest Image: image_1679392267_560186102.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_560186102.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_560186102.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_560186102.png
# Processing Point Cloud: cloud_1679392267_648480768.ply -> Closest Image: image_1679392267_660184202.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_660184202.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_660184202.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_660184202.png
# Processing Point Cloud: cloud_1679392267_748391936.ply -> Closest Image: image_1679392267_760182202.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_760182202.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_760182202.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_760182202.png
# Processing Point Cloud: cloud_1679392267_848382976.ply -> Closest Image: image_1679392267_860180202.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_860180202.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_860180202.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_860180202.png
# Processing Point Cloud: cloud_1679392267_948440320.ply -> Closest Image: image_1679392267_960178202.png
# Saving overlay image for cam_front at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_front/image_1679392267_960178202.png
# Saving overlay image for cam_left at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_left/image_1679392267_960178202.png
# Saving overlay image for cam_right at /sata_ssd/digiforest_rosbags/extracted/2023_04_exp06_m3/overlay/cam_right/image_1679392267_960178202.png
# Processing Point Cloud: cloud_1679392268_048590336.ply -> Closest Image: image_1679392268_60176302.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 53
#      51     x, y = lidar_points_image[i]
#      52     color = tuple(int(c) for c in depth_colors[i])  # Convert to tuple for cv2
# ---> 53     cv2.circle(image_temp, (x, y), radius=3, color=color, thickness=-1)  # filled circle
#      55 output_dir = os.path.join(slam_folder, "overlay", camera.label)
#      56 os.makedirs(output_dir, exist_ok=True)
#
# KeyboardInterrupt:
